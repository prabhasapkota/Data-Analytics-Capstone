# %%
import pandas as pd

# Load datasets
datasets = {
    "Production Indices": pd.read_csv('cleaned_fao_data_production_indices_data.csv'),
    "Land Use": pd.read_csv('cleaned_fao_data_land_data.csv'),
    "Fertilizer Use": pd.read_csv('cleaned_fao_data_fertilizers_data.csv')
}

# %% [markdown]
# # Initial Data Inspection

# %%
import pandas as pd

# Load datasets into a dictionary (replace file paths with actual file locations)
datasets = {
    "Production Indices": pd.read_csv('cleaned_fao_data_production_indices_data.csv'),
    "Land Use": pd.read_csv('cleaned_fao_data_land_data.csv'),
    "Fertilizer Use": pd.read_csv('cleaned_fao_data_fertilizers_data.csv')
}

# Iterate through each dataset for initial inspection
for name, df in datasets.items():
    print(f"\n--- Initial Data Inspection for {name} Dataset ---")
    
    # Display basic info (structure, column data types, and non-null counts)
    print("\nBasic Info:")
    print(df.info())
    
    # Display the first few rows to understand the general structure
    print("\nFirst Few Rows:")
    print(df.head())
    
    # Check for missing values in each column
    print("\nMissing Values:")
    print(df.isnull().sum())
    
    # Check for duplicate rows
    print("\nDuplicate Rows:")
    duplicates = df.duplicated().sum()
    print(f"Number of duplicate rows: {duplicates}")

    # Summary to indicate completion of inspection for each dataset
    print(f"\n--- Completed Initial Inspection for {name} Dataset ---\n")
# Out:
# --- Initial Data Inspection for Production Indices Dataset ---
#
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234533 entries, 0 to 234532
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   country_or_area  234533 non-null  object
#  1   element_code     234533 non-null  int64
#  2   element          234533 non-null  object
#  3   year             234533 non-null  int64
#  4   unit             234533 non-null  object
#  5   value            234533 non-null  float64
#  6   value_footnotes  234533 non-null  object
#  7   category         234533 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 14.3+ MB
# None
#
# First Few Rows:
#   country_or_area  element_code                               element  year  \
# 0     Afghanistan           152  Gross Production 1999-2001 (1000 I$)  2007
# ...

# %% [markdown]
# # Initial Descriptive Statistics

# %%
import pandas as pd

# Load datasets into a dictionary (replace file paths with actual file locations)
datasets = {
   "Production Indices": pd.read_csv('cleaned_fao_data_production_indices_data.csv'),
    "Land Use": pd.read_csv('cleaned_fao_data_land_data.csv'),
    "Fertilizer Use": pd.read_csv('cleaned_fao_data_fertilizers_data.csv')
}

# Iterate through each dataset to calculate and display descriptive statistics
for name, df in datasets.items():
    print(f"\n--- Initial Descriptive Statistics for {name} Dataset ---")
    
    # Calculate descriptive statistics for numerical columns
    print("\nDescriptive Statistics for Numerical Columns:")
    print(df.describe())
    
    # Calculate descriptive statistics for categorical columns
    print("\nDescriptive Statistics for Categorical Columns:")
    categorical_columns = df.select_dtypes(include=['object']).columns  # Select object type columns
    for col in categorical_columns:
        print(f"\nColumn: {col}")
        print(df[col].value_counts().head(10))  # Show top 10 most frequent values for each categorical column

    # Summary to indicate completion of descriptive statistics for each dataset
    print(f"\n--- Completed Descriptive Statistics for {name} Dataset ---\n")
# Out:
# --- Initial Descriptive Statistics for Production Indices Dataset ---
#
# Descriptive Statistics for Numerical Columns:
#         element_code           year         value
# count  234533.000000  234533.000000  2.345330e+05
# mean      318.798821    1984.023928  5.341476e+06
# std       138.323340      13.632982  4.161196e+07
# min       152.000000    1961.000000  0.000000e+00
# 25%       154.000000    1972.000000  8.800000e+01
# 50%       432.000000    1984.000000  1.220000e+02
# 75%       434.000000    1996.000000  2.277920e+05
# max       438.000000    2007.000000  1.692538e+09
#
# Descriptive Statistics for Categorical Columns:
#
# Column: country_or_area
# country_or_area
# Eastern Europe +    1285
# Romania             1246
# Bulgaria            1246
# Switzerland         1245
# Iraq                1240
# Cape Verde          1239
# Canada              1216
# Hungary             1215
# Poland              1196
# Ecuador             1196
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# # Initial Data Distribution for Numerical Columns

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets into a dictionary (replace file paths with actual file locations)
datasets = {
     "Production Indices": pd.read_csv('cleaned_fao_data_production_indices_data.csv'),
    "Land Use": pd.read_csv('cleaned_fao_data_land_data.csv'),
    "Fertilizer Use": pd.read_csv('cleaned_fao_data_fertilizers_data.csv')
}

# Iterate through each dataset for plotting distributions
for name, df in datasets.items():
    print(f"\n--- Initial Data Distribution for Numerical Columns in {name} Dataset ---")
    
    # Select numerical columns
    numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

    # Plot histograms for each numerical column
    for col in numerical_columns:
        plt.figure(figsize=(8, 4))
        plt.hist(df[col].dropna(), bins=30, edgecolor='k', alpha=0.7)
        plt.title(f'{col} Distribution in {name} Dataset')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

    print(f"Completed Distribution Plots for {name} Dataset\n")
# Out:
# --- Initial Data Distribution for Numerical Columns in Production Indices Dataset ---
# Completed Distribution Plots for Production Indices Dataset
#
#
# --- Initial Data Distribution for Numerical Columns in Land Use Dataset ---
# Completed Distribution Plots for Land Use Dataset
#
#
# --- Initial Data Distribution for Numerical Columns in Fertilizer Use Dataset ---
# Completed Distribution Plots for Fertilizer Use Dataset

# %% [markdown]
# # Initial Data Distribution for Categorical Columns

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets into a dictionary (replace file paths with actual file locations)
datasets = {
    "Production Indices": pd.read_csv('cleaned_fao_data_production_indices_data.csv'),
    "Land Use": pd.read_csv('cleaned_fao_data_land_data.csv'),
    "Fertilizer Use": pd.read_csv('cleaned_fao_data_fertilizers_data.csv')   
}

# Iterate through each dataset to plot distributions for categorical columns
for name, df in datasets.items():
    print(f"\n--- Initial Data Distribution for Categorical Columns in {name} Dataset ---")
    
    # Select categorical columns
    categorical_columns = df.select_dtypes(include=['object']).columns

    # Plot bar charts for each categorical column
    for col in categorical_columns:
        plt.figure(figsize=(10, 5))
        df[col].value_counts().head(10).plot(kind='bar', color='skyblue', edgecolor='k')
        plt.title(f'{col} Distribution in {name} Dataset')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.xticks(rotation=45)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

    print(f"Completed Distribution Plots for {name} Dataset\n")
# Out:
# --- Initial Data Distribution for Categorical Columns in Production Indices Dataset ---
# Completed Distribution Plots for Production Indices Dataset
#
#
# --- Initial Data Distribution for Categorical Columns in Land Use Dataset ---
# Completed Distribution Plots for Land Use Dataset
#
#
# --- Initial Data Distribution for Categorical Columns in Fertilizer Use Dataset ---
# Completed Distribution Plots for Fertilizer Use Dataset

# %% [markdown]
# # Initial Data Preparation (or Data Preprocessing)

# %%
import pandas as pd

# Load datasets into a dictionary (replace file paths with actual file locations)
datasets = {
     "Production Indices": pd.read_csv('cleaned_fao_data_production_indices_data.csv'),
    "Land Use": pd.read_csv('cleaned_fao_data_land_data.csv'),
    "Fertilizer Use": pd.read_csv('cleaned_fao_data_fertilizers_data.csv')
}

# Data Preparation Process for Each Dataset
for name, df in datasets.items():
    print(f"\n--- Data Preparation for {name} Dataset ---")
    
    # 1. Handling Missing Values
    # Impute numerical columns with mean or median
    numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
    for col in numerical_columns:
        df[col].fillna(df[col].mean(), inplace=True)

    # Fill missing values in categorical columns with the mode
    categorical_columns = df.select_dtypes(include=['object']).columns
    for col in categorical_columns:
        df[col].fillna(df[col].mode()[0], inplace=True)

    # 2. Standardizing Data Types
    # Ensure 'year' column is in integer format
    if 'year' in df.columns:
        df['year'] = pd.to_numeric(df['year'], errors='coerce').astype('Int64')

    # 3. Encoding Categorical Variables (if needed for analysis)
    # Convert categorical columns to category dtype to save memory or use label encoding if needed
    for col in categorical_columns:
        df[col] = df[col].astype('category')
    
    # 4. Removing Duplicates
    # Drop duplicate rows
    df.drop_duplicates(inplace=True)

    # Display a summary of the changes
    print(f"{name} Dataset - Missing Values After Imputation:")
    print(df.isnull().sum())
    print(f"{name} Dataset - Number of Rows and Columns After Cleaning: {df.shape}")
# Out:
# --- Data Preparation for Production Indices Dataset ---
# Production Indices Dataset - Missing Values After Imputation:
# country_or_area    0
# element_code       0
# element            0
# year               0
# unit               0
# value              0
# value_footnotes    0
# category           0
# dtype: int64
# Production Indices Dataset - Number of Rows and Columns After Cleaning: (234533, 8)
#
# --- Data Preparation for Land Use Dataset ---
# Land Use Dataset - Missing Values After Imputation:
# country_or_area    0
# element_code       0
# element            0
# year               0
# unit               0
# value              0
# value_footnotes    0
# category           0
# dtype: int64
# Land Use Dataset - Number of Rows and Columns After Cleaning: (104659, 8)
#
# --- Data Preparation for Fertilizer Use Dataset ---
# Fertilizer Use Dataset - Missing Values After Imputation:
# country_or_area    0
# element_code       0
# element            0
# year               0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets into a dictionary (replace file paths with actual file locations)
datasets = {
     "Production Indices": pd.read_csv('cleaned_fao_data_production_indices_data.csv'),
    "Land Use": pd.read_csv('cleaned_fao_data_land_data.csv'),
    "Fertilizer Use": pd.read_csv('cleaned_fao_data_fertilizers_data.csv')
    
}

# Define the important columns in each dataset for visualization
important_columns = {
    "Production Indices": ['year', 'value', 'category', 'country_or_area'],
    "Land Use": ['year', 'value', 'category', 'country_or_area'],
    "Fertilizer Use": ['year', 'value', 'category', 'country_or_area']
}

# Visualize each dataset
for name, df in datasets.items():
    print(f"\n--- Initial Visualizations for {name} Dataset ---")
    
    # Filter the dataframe to include only the necessary columns
    df = df[important_columns[name]]
    
    # 1. Time Series Plot for 'value' over 'year' (Trend Analysis)
    plt.figure(figsize=(10, 5))
    sns.lineplot(data=df, x='year', y='value', hue='category', estimator='mean', ci=None)
    plt.title(f"{name} - Average Value Over Time")
    plt.xlabel("Year")
    plt.ylabel("Value")
    plt.legend(title='Category')
    plt.grid(True)
    plt.show()
    
    # 2. Bar Plot for 'value' by 'category' (Category Distribution)
    plt.figure(figsize=(10, 5))
    sns.barplot(data=df, x='category', y='value', estimator='mean', ci=None, palette='viridis')
    plt.title(f"{name} - Average Value by Category")
    plt.xlabel("Category")
    plt.ylabel("Average Value")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

    # 3. Box Plot for 'value' by 'country_or_area' (Outlier Detection)
    plt.figure(figsize=(12, 6))
    top_countries = df['country_or_area'].value_counts().index[:10]
    sns.boxplot(data=df[df['country_or_area'].isin(top_countries)], x='country_or_area', y='value', palette='Set2')
    plt.title(f"{name} - Distribution of Value by Top 10 Countries")
    plt.xlabel("Country or Area")
    plt.ylabel("Value")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

    print(f"Completed Visualizations for {name} Dataset\n")
# Out:
# --- Initial Visualizations for Production Indices Dataset ---
# /var/folders/jt/crfp8jt53r547cy9xvkqj3s40000gn/T/ipykernel_85413/413860785.py:29: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x='year', y='value', hue='category', estimator='mean', ci=None)
# /Users/prabha/Documents/CSIS-44608/datafun-04-notebooks/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/prabha/Documents/CSIS-44608/datafun-04-notebooks/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
